# %% [markdown]
# <a href="https://colab.research.google.com/github/mochradja/DataScience/blob/main/Data_minimarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Insight 3 dan 4
#
# M. Radja B.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 df = pd.read_excel('sample_data/Data-minimarket.xlsx')
df['Hari'] = df['Tanggal'].dt.day
df['Bulan'] = df['Tanggal'].dt.month
df['Tahun'] = df['Tanggal'].dt.year
df
# Out:
#        Tanggal  PLU                Description   Sales  Struk  QTY Sales  \
# 0   2019-01-01  234             DJI SAM SOE 12  123200      5          7
# 1   2019-01-01  719          MD EGG DROPS 110G    7000      1          1
# 2   2019-01-02  234             DJI SAM SOE 12   35200      2          2
# 3   2019-01-03  234             DJI SAM SOE 12   17600      1          1
# 4   2019-01-03  374  KG AST BISC RED CAN 1600G   80818      1          1
# ..         ...  ...                        ...     ...    ...        ...
# 969 2020-09-28  234             DJI SAM SOE 12   36800      1          2
# 970 2020-09-28  719          MD EGG DROPS 110G    6818      1          1
# 971 2020-09-29  234             DJI SAM SOE 12   18400      1          1
# 972 2020-09-29  719          MD EGG DROPS 110G    6818      1          1
# 973 2020-09-30  234             DJI SAM SOE 12   18400      1          1
#
#      Hari  Bulan  Tahun
# 0       1      1   2019
# 1       1      1   2019
# ...

# %%
data = df['Sales'].groupby(df.Bulan).agg(['sum', 'count']).reset_index()
data_max_min = data[(data['sum'] == data['sum'].max()) | (data['sum'] == data['sum'].min())] 
data_max_min
# Out:
#     Bulan       sum  count
# 4       5  13104424    128
# 11     12    755550     36

# %%
sales = df['Sales'].groupby(df.Bulan).agg('sum').reset_index()
sales
# Out:
#     Bulan     Sales
# 0       1   3005396
# 1       2   2224279
# 2       3   2895606
# 3       4   3394266
# 4       5  13104424
# 5       6   6214132
# 6       7   2719846
# 7       8   2457060
# 8       9   2429758
# 9      10   1173837
# 10     11   1617477
# 11     12    755550

# %%
# plt.bar(df.Bulan, df.Sales)
# plt.xticks(df.Bulan)
# plt.ylabel("Sales")
# plt.xlabel("Bulan")
# plt.title("Performa Penjualan Bulanan")
# plt.show()

# plt.bar(data.COUNTRY, data['count'])

plt.figure(figsize = (10,5)) #ukuran skala gambar
plt.rcParams.update({'font.size': 10, 'font.weight' : 'bold'}) #ukuran font

plt.bar(data.Bulan, data['count'], width = 0.7) #lebar kotak bar
plt.xticks(df.Bulan)
plt.xlabel('Penjualan per Negara') #label nama 
plt.ylabel('Penjualan', fontdict={'fontweight':'bold'})
plt.title('Negara', fontdict={'fontweight':'bold'})

plt.xticks(rotation = 90)
plt.yticks(rotation = 45)

plt.show()

# %%
df['Hari'] = df['Tanggal'].dt.day
data = df['Struk'].groupby(df.Hari).agg(['sum'])
data
# Out:
#       sum
# Hari
# 1      74
# 2      52
# 3      45
# 4      79
# 5      61
# 6      44
# 7      46
# 8      53
# 9      53
# 10     62
# 11     48
# 12     45
# 13     48
# 14     52
# 15     52
# 16     54
# 17     48
# 18     53
# 19     54
# 20     45
# 21     57
# 22     48
# 23     62
# 24     62
# 25     40
# 26     45
# 27     58
# 28     63
# 29     51
# 30     61
# 31     44

# %%
plt.bar(df.Bulan, df.Struk)
plt.xticks(df.Bulan)
plt.ylabel("Struk")
plt.xlabel("Jumlah Bulan")
plt.title("Performa Penjualan Bulanan")
plt.xticks(rotation=90)
plt.show()
